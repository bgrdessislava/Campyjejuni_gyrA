# %%
import pandas as pd
import pickle

# %%
pwd
# Out:
# '/Users/user/Library/CloudStorage/OneDrive-Nexus365/PhD/Campy_Analysis_ALL/Code/Non_r'

# %%
df_train = pd.read_excel('../../Data/X_train_20.xlsx')
df_test = pd.read_excel('../../Data/X_test_20.xlsx')

# %%
df = pd.concat([df_train,df_test]).drop(['Unnamed: 0','trainNG-20'],axis=1)

# %%
df
# Out:
#       aspA  glnA  gltA  glyA  pgm  tkt  uncA  ST (MLST) clonal_complex (MLST)  \
# 0        2     1     1     3    2    1     5         21         ST-21 complex
# 1        1     2     3     4    5    9     3         42         ST-42 complex
# 2        7    17     2    15   23    3    12         51        ST-443 complex
# 3        9     2     4    62    4  133     6        990        ST-257 complex
# 4        4     7    10     4   42   51     1        583         ST-45 complex
# ...    ...   ...   ...   ...  ...  ...   ...        ...                   ...
# 2067     2     4     1     2    7    1     5         48         ST-48 complex
# 2068     2     4     1     4   19   62     5        475         ST-48 complex
# 2069     4     7    12     4   42   51     1        383        ST-283 complex
# 2070     2     1    21     3    2    1     5         53         ST-21 complex
# 2071     2     1    42     3  148    1     5        861         ST-21 complex
#
#       fullNG-20
# ...

# %%
# load the model from disk
filename = '../../Data/aspA-glnA-gltA-glyA-pgm-tkt-uncA-trained.pkl'
with open(filename, 'rb') as fh:
    model = pickle.load(fh)

# %%
col_names = ['aspA','glnA','gltA','glyA','pgm','tkt','uncA']

# %%
model.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# _catboost.pyx in _catboost.get_float_feature()
#
# _catboost.pyx in _catboost._FloatOrNan()
#
# _catboost.pyx in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'ST-21 complex'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-15-33074de249d5> in <module>
# ----> 1 model.predict(df)
#
# /opt/anaconda3/lib/python3.8/site-packages/catboost/core.py in predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    4822                   with log probability for every class for each object.
#    4823         """
# -> 4824         return self._predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, 'predict', task_type)
#    4825
# ...
