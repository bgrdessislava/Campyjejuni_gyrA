# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
import catboost
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from itertools import combinations
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics.cluster import adjusted_rand_score

# %%
path = '../../Data/MLST7_NG20'

# %%
df = []
file = f'{path}/combined_NG20_7MLST.txt'
with open(file) as fh:
    for line in fh:
        data = line.strip().split('\t')
        group = tuple(data[0].split('-'))
        score = float(data[1])
        n = len(group)
        df.append([group, score, n])
df = pd.DataFrame(df, columns=['loci', 'score', 'n'])

# %%
lociMerge = []
loci = ['gltA', 'uncA', 'tkt', 'aspA', 'glyA', 'pgm']
for locus in loci:
    sub = df.loc[df['loci'].apply(lambda x: locus in x)]
    sub['l']
    lociMerge.append(sub)
lociMerge = pdlociMerge
# Out:
#                  loci     score  n
# 0             (gltA,)  0.345795  1
# 10        (gltA, tkt)  0.493762  2
# 14       (gltA, uncA)  0.530718  2
# 16  (gltA, tkt, uncA)  0.580642  3
# 20       (aspA, gltA)  0.617721  2
#                  loci     score  n
# 1             (uncA,)  0.353777  1
# 5         (tkt, uncA)  0.428723  2
# 6        (aspA, uncA)  0.437585  2
# 8   (aspA, tkt, uncA)  0.464488  3
# 11        (pgm, uncA)  0.510258  2
#                  loci     score  n
# 2              (tkt,)  0.355697  1
# 5         (tkt, uncA)  0.428723  2
# 7         (aspA, tkt)  0.446696  2
# 8   (aspA, tkt, uncA)  0.464488  3
# 10        (gltA, tkt)  0.493762  2
#                  loci     score  n
# 3             (aspA,)  0.366377  1
# 6        (aspA, uncA)  0.437585  2
# 7         (aspA, tkt)  0.446696  2
# 8   (aspA, tkt, uncA)  0.464488  3
# 17        (aspA, pgm)  0.598954  2
#             loci     score  n
# 4        (glyA,)  0.427203  1
# 18   (glyA, tkt)  0.609856  2
# 19  (glnA, glyA)  0.610995  2
# 22  (aspA, glyA)  0.627075  2
# 23   (glyA, pgm)  0.629840  2
#                 loci     score  n
# 9             (pgm,)  0.481644  1
# 11       (pgm, uncA)  0.510258  2
# 12  (pgm, tkt, uncA)  0.516888  3
# 13        (pgm, tkt)  0.529128  2
# 17       (aspA, pgm)  0.598954  2

# %%
meanScore = []
for locus in loci:
    sub = df.loc[df['loci'].apply(lambda x: locus in x)]
    meanScore.append(sub.groupby('n')['score'].mean().rename(locus))
meanScore = (
    pd.concat(meanScore, axis=1)
    .reset_index()
    .melt(id_vars='n', var_name='locus', value_name='score')
)

# %%
MLST_7_assignment_score = sns.lineplot(x='n', y='score', hue='locus', data=meanScore)

# %%
MLST_7_assignment_score, ax = plt.subplots(figsize=(7,5))
sns.lineplot(x='n', y='score', hue='locus', data=meanScore,ax=ax)
MLST_7_assignment_score.savefig('../../Figures/MLST_AssighnmentScore.pdf')

# %%
sub
# Out:
#                                    loci     score  n
# 0                    (glnA, gltA, uncA)  0.930329  3
# 1              (aspA, gltA, glyA, uncA)  0.968853  4
# 2                          (glnA, uncA)  0.658456  2
# 6                    (glnA, glyA, uncA)  0.712224  3
# 7                           (tkt, uncA)  0.421275  2
# ..                                  ...       ... ..
# 119             (aspA, glyA, tkt, uncA)  0.738148  4
# 121              (aspA, pgm, tkt, uncA)  0.734375  4
# 122       (aspA, gltA, glyA, tkt, uncA)  0.972892  5
# 124       (aspA, glnA, glyA, tkt, uncA)  0.756498  5
# 126  (aspA, gltA, glyA, pgm, tkt, uncA)  0.982722  6
#
# [64 rows x 3 columns]
